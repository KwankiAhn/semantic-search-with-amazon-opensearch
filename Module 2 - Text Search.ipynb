# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:96% !important; }</style>"))
# Out:
# <style>.container { width:96% !important; }</style>

# %% [markdown]
# # Module 2: Text Search with Amazon OpenSearch Service
#
# In this module, we are going to perform a simple search in OpenSearch by matching the individual words in our search query. We will:
# 1. Load data into OpenSearch from the Amazon Product Question and Answer (PQA) dataset. This dataset contains a list of common questions and answers related to products.
# 2. Query the data using a simple query search for find potentially matching questions. We will search the PQA dataset for questions similar to our sample question "does this work with xbox?". We expect to find matches in the dataset based on the individual words such as "xbox" and "work".
#
# In subsequent modules, we will then demonstrate how to use semantic search to improve the relvance of the query results.

# %% [markdown]
# ### 1. Install required libraries

# %% [markdown]
# Before we begin, we need to install some required libraries.

# %%
# !pip install -q boto3
# !pip install -q requests
# !pip install -q requests-aws4auth
# !pip install -q opensearch-py
# !pip install -q tqdm
# !pip install -q boto3
# !pip install -q install transformers[torch]
# !pip install -q transformers
# !pip install -q sentence-transformers rank_bm25

# %% [markdown]
# ### 2. Get Cloud Formation stack output variables
#
# We also need to grab some key values from the infrastructure we provisioned using CloudFormation. To do this, we will list the outputs from the stack and store this in "outputs" to be used later.
#
# You can ignore any "PythonDeprecationWarning" warnings.

# %%
import boto3
import json

cfn = boto3.client('cloudformation')
kms = boto3.client('secretsmanager')


def get_cfn_outputs(stackname):
    outputs = {}
    for output in cfn.describe_stacks(StackName=stackname)['Stacks'][0]['Outputs']:
        outputs[output['OutputKey']] = output['OutputValue']
    return outputs

## Setup variables to use for the rest of the demo
cloudformation_stack_name = "semantic-search"

outputs = get_cfn_outputs(cloudformation_stack_name)
bucket = outputs['s3BucketTraining']
aos_host = outputs['OpenSearchDomainEndpoint']
aos_credentials = json.loads(kms.get_secret_value(SecretId=outputs['OpenSearchSecret'])['SecretString'])

outputs

# %% [markdown]
# ### 3. Copy the data set locally
# Before we can run any queries, we need to download the Amazon Product Question and Answer data from : https://registry.opendata.aws/amazon-pqa/

# %% [markdown]
# Let's start by having a look at all the files in the dataset.

# %%
# !aws s3 ls --no-sign-request s3://amazon-pqa/
# Out:
# 2021-05-20 22:11:25 2267692311 amazon-pqa.tar.gz
# 2021-05-09 20:53:53  442066567 amazon_pqa_accessories.json
# 2021-05-09 20:53:49  275062405 amazon_pqa_activity_&_fitness_trackers.json
# 2021-05-09 20:53:49  127094083 amazon_pqa_adapters.json
# 2021-05-09 20:53:49  143639699 amazon_pqa_amazon_echo_&_alexa_devices.json
# 2021-05-09 20:53:49  106017252 amazon_pqa_area_rugs.json
# 2021-05-09 20:53:49  164430689 amazon_pqa_backpacks.json
# 2021-05-09 20:53:49  679285046 amazon_pqa_basic_cases.json
# 2021-05-09 20:53:49  390964941 amazon_pqa_batteries.json
# 2021-05-09 20:53:49  107896488 amazon_pqa_battery_chargers.json
# 2021-05-09 20:53:49   77113272 amazon_pqa_bed_frames.json
# 2021-05-09 20:53:49  157944761 amazon_pqa_beds.json
# 2021-05-09 20:53:49  218133567 amazon_pqa_bullet_cameras.json
# 2021-05-09 20:53:50  118106256 amazon_pqa_camcorders.json
# 2021-05-09 20:53:50   71239417 amazon_pqa_car.json
# 2021-05-09 20:53:50  137487049 amazon_pqa_car_stereo_receivers.json
# 2021-05-09 20:53:50  153301436 amazon_pqa_carrier_cell_phones.json
# 2021-05-09 20:53:50  331996893 amazon_pqa_cases.json
# 2021-05-09 20:53:50  194789327 amazon_pqa_casual.json
# 2021-05-09 20:53:50  138252584 amazon_pqa_chairs.json
# 2021-05-09 20:53:50  112165408 amazon_pqa_chargers_&_adapters.json
# 2021-05-09 20:53:50  250693003 amazon_pqa_code_readers_&_scan_tools.json
# 2021-05-09 20:53:50   68079458 amazon_pqa_computer_cases.json
# 2021-05-09 20:53:50   77977101 amazon_pqa_consoles.json
# 2021-05-09 20:53:50  197194037 amazon_pqa_costumes.json
# 2021-05-09 20:53:50  202777974 amazon_pqa_cradles.json
# 2021-05-09 20:53:50  159496851 amazon_pqa_diffusers.json
# 2021-05-09 20:53:50   86792506 amazon_pqa_dolls.json
# 2021-05-09 20:53:50  319608519 amazon_pqa_dome_cameras.json
# 2021-05-09 20:53:50  699110395 amazon_pqa_earbud_headphones.json
# 2021-05-09 20:53:50   67925281 amazon_pqa_external_hard_drives.json
# 2021-05-09 20:53:50   90896757 amazon_pqa_fashion_sneakers.json
# 2021-05-09 20:53:50   98297179 amazon_pqa_floor_mats.json
# 2021-05-09 20:53:50  103299169 amazon_pqa_food_storage_&_organization_sets.json
# 2021-05-09 20:53:50  241697772 amazon_pqa_games.json
# 2021-05-09 20:53:50   77147759 amazon_pqa_graphics_cards.json
# 2021-05-09 20:53:50  212819467 amazon_pqa_gun_holsters.json
# 2021-05-09 20:53:50  158306869 amazon_pqa_hair_extensions.json
# 2021-05-09 20:53:50  138854761 amazon_pqa_handheld_flashlights.json
# 2021-05-09 20:53:50  152627057 amazon_pqa_headlight_&_tail_light_conversion_kits.json
# 2021-05-09 20:53:50  132272824 amazon_pqa_headlight_assemblies.json
# 2021-05-09 20:53:50  131253948 amazon_pqa_headlight_bulbs.json
# 2021-05-09 20:53:50  170374172 amazon_pqa_headsets.json
# 2021-05-09 20:53:50  160305063 amazon_pqa_hidden_cameras.json
# 2021-05-09 20:53:50   95549762 amazon_pqa_home_office_desks.json
# 2021-05-09 20:53:50  203914292 amazon_pqa_home_security_systems.json
# 2021-05-09 20:53:50   97187448 amazon_pqa_in-dash_dvd_&_video_receivers.json
# 2021-05-09 20:53:50  212843244 amazon_pqa_in-dash_navigation.json
# 2021-05-09 20:53:50  134353943 amazon_pqa_inkjet_printers.json
# 2021-05-09 20:53:50   85768704 amazon_pqa_jeans.json
# 2021-05-09 20:53:50  128135277 amazon_pqa_keyboards.json
# 2021-05-09 20:53:50  116416000 amazon_pqa_landline_phones.json
# 2021-05-09 20:53:50  178273635 amazon_pqa_led_&_lcd_tvs.json
# 2021-05-09 20:53:50  300261569 amazon_pqa_led_bulbs.json
# 2021-05-09 20:53:50  210506735 amazon_pqa_led_strip_lights.json
# 2021-05-09 20:53:51  102910564 amazon_pqa_light_bars.json
# 2021-05-09 20:53:51   96573585 amazon_pqa_masks.json
# 2021-05-09 20:53:51  152793447 amazon_pqa_mattresses.json
# 2021-05-09 20:53:51   94675352 amazon_pqa_memory.json
# 2021-05-09 20:53:51  281321641 amazon_pqa_monitors.json
# 2021-05-09 20:53:51   78448528 amazon_pqa_motherboards.json
# 2021-05-09 20:53:51  150541937 amazon_pqa_mp3_&_mp4_players.json
# 2021-05-09 20:53:51  278177567 amazon_pqa_on-dash_cameras.json
# 2021-05-09 20:53:51  278531682 amazon_pqa_over-ear_headphones.json
# 2021-05-09 20:53:51  147083447 amazon_pqa_panels.json
# 2021-05-09 20:53:51   88634925 amazon_pqa_pants.json
# 2021-05-09 20:53:51  358988080 amazon_pqa_portable_bluetooth_speakers.json
# 2021-05-09 20:53:51   89016682 amazon_pqa_posters_&_prints.json
# 2021-05-09 20:53:51  116017016 amazon_pqa_power_converters.json
# 2021-05-09 20:53:51  100128300 amazon_pqa_pumps.json
# 2021-05-09 20:53:51  172268436 amazon_pqa_quadcopters_&_multirotors.json
# 2021-05-09 20:53:51   97803297 amazon_pqa_receivers.json
# 2021-05-09 20:53:51  171552858 amazon_pqa_remote_controls.json
# 2021-05-09 20:53:51  176770768 amazon_pqa_repellents.json
# 2021-05-09 20:53:51  151415809 amazon_pqa_routers.json
# 2021-05-09 20:53:51  240899181 amazon_pqa_screen_protectors.json
# 2021-05-09 20:53:51  120357793 amazon_pqa_sets.json
# 2021-05-09 20:53:51  116292067 amazon_pqa_sheet_&_pillowcase_sets.json
# 2021-05-09 20:53:52   88400141 amazon_pqa_slr_camera_lenses.json
# 2021-05-09 20:53:52  336801174 amazon_pqa_smartwatches.json
# 2021-05-09 20:53:52   83154297 amazon_pqa_sound_bars.json
# 2021-05-09 20:53:52  144038367 amazon_pqa_sports_&_action_video_cameras.json
# 2021-05-09 20:53:52  132584223 amazon_pqa_sports_water_bottles.json
# 2021-05-09 20:53:52  158685791 amazon_pqa_stands.json
# 2021-05-09 20:53:52  320663018 amazon_pqa_streaming_media_players.json
# 2021-05-09 20:53:52  169509230 amazon_pqa_string_lights.json
# 2021-05-09 20:53:52  165270811 amazon_pqa_sunglasses.json
# 2021-05-09 20:53:52  216048049 amazon_pqa_surveillance_dvr_kits.json
# 2021-05-09 20:53:53  154666084 amazon_pqa_t-shirts.json
# 2021-05-09 20:53:52  367319312 amazon_pqa_tablets.json
# 2021-05-09 20:53:53  142983066 amazon_pqa_towers.json
# 2021-05-09 20:53:53  403702059 amazon_pqa_traditional_laptops.json
# 2021-05-09 20:53:53  120175498 amazon_pqa_tv_antennas.json
# 2021-05-09 20:53:53  161324981 amazon_pqa_tv_ceiling_&_wall_mounts.json
# 2021-05-09 20:53:53  821444488 amazon_pqa_unlocked_cell_phones.json
# 2021-05-09 20:53:53  121908382 amazon_pqa_usb_cables.json
# 2021-05-09 20:53:53   99049271 amazon_pqa_usb_flash_drives.json
# 2021-05-09 20:53:53  119377555 amazon_pqa_vehicle_backup_cameras.json
# 2021-05-09 20:53:53  243675719 amazon_pqa_video_projectors.json
# 2021-05-09 20:53:53  187965637 amazon_pqa_wigs.json
# 2021-05-09 20:53:53  252079672 amazon_pqa_wrist_watches.json
# 2021-06-03 21:27:12      10043 readme.txt

# %% [markdown]
# There are a lot of files here, so for the purposes of this demo, we focus on just the headset data. Let's download the amazon_pqa_headsets.json data locally.

# %%
# !aws s3 cp --no-sign-request s3://amazon-pqa/amazon_pqa_headsets.json ./amazon-pqa/amazon_pqa_headsets.json
# Out:
# download: s3://amazon-pqa/amazon_pqa_headsets.json to amazon-pqa/amazon_pqa_headsets.json

# %% [markdown]
# ### 4. Create an OpenSearch cluster connection.
# Next, we'll use Python API to set up connection with Amazon Opensearch Service domain.
#
# Note: if you're using a region other than us-east-1, please update the region in the code below.

# %%
# KwankiAhn Settings
aos_host = "search-search-test-fsnokwgicqo2bvwylh4ahuk2ru.us-east-1.es.amazonaws.com"
aos_credentials = {
    "username": "AK...",
    "password": "XT..."
}

# %%
from opensearchpy import OpenSearch, RequestsHttpConnection, AWSV4SignerAuth
import boto3

#update the region if you're working other than us-east-1
region = 'us-east-1' 

credentials = boto3.Session().get_credentials()
auth = AWSV4SignerAuth(credentials, region)
# auth = (aos_credentials['username'], aos_credentials['password'])

aos_client = OpenSearch(
    hosts = [{'host': aos_host, 'port': 443}],
    http_auth = auth,
    use_ssl = True,
    verify_certs = True,
    connection_class = RequestsHttpConnection
)

# %% [markdown]
# ### 5. Create a index in Amazon Opensearch Service
# We are defining an index with english analyzer which will strip the common stopwords like `the`, `is`, `a`, `an`, etc..
#
# We will use the aos_client connection we initiated ealier to create an index in Amazon OpenSearch Service

# %%
headset_default_index = {
    "settings": {
        "number_of_replicas": 1,
        "number_of_shards": 1,
        "analysis": {
            "analyzer": {
                "default": {
                    "type": "standard",
                    "stopwords": "_english_"
                }
            }
        }
    },
#     "mappings": {
#         "properties": {
#             "question": {
#                 "type": "text",
#                 "store": True
#             }
#         }
#     }
#     "mappings": {
#         "_source": {"enabled": True}, 
#         "properties": {
#             "question": {"type": "text"}
#         }
#     }
#     "mappings": {
#         'properties': {
#             'question': {'type': 'text'}
#         }
#     }           
}
# KwankiAhn 231225 Remark
# Error : Exception raised even though number of shard copies is a multiple of awareness attributes
# Solution : Open search domain 설정을 3AZ -> 1AZ Only 로 설정시 해결 (number_of_replicas 파라미터가 실제 노드 구성 Configuration 과 맞아야 하는 것으로 보임)

# %% [markdown]
# If for any reason you need to recreate your dataset, you can uncomment and execute the following to delete any previously created indexes. If this is the first time you're running this, you can skip this step.

# %%
aos_client.indices.delete(index="headset_pqa")
# Out:
# {'acknowledged': True}

# %% [markdown]
# Using the above index definition, we now need to create the index in Amazon OpenSearch

# %%
ret = aos_client.indices.create(index="headset_pqa")  #,body=headset_default_index,ignore=400)

# %%
import json
def displayPrettyJson(json_data):
    if type(json_data) is str:
        json_object = json.loads(json_data)
    else:
        json_object = json_data
    json_formatted_str = json.dumps(json_object, indent=2)
    print(json_formatted_str)
displayPrettyJson(ret)
# Out:
# {
#   "acknowledged": true,
#   "shards_acknowledged": true,
#   "index": "headset_pqa"
# }

# %% [markdown]
# Let's verify the created index information

# %%
aos_client.indices.get(index="headset_pqa")
# Out:
# {'headset_pqa': {'aliases': {},
#   'mappings': {},
#   'settings': {'index': {'replication': {'type': 'DOCUMENT'},
#     'number_of_shards': '5',
#     'provided_name': 'headset_pqa',
#     'creation_date': '1703680478113',
#     'number_of_replicas': '1',
#     'uuid': 'ysTtonrXSuWPU-O1Ij1opg',
#     'version': {'created': '136327827'}}}}}

# %% [markdown]
# ### 6. Load the raw data into the Index
# Next, let's load the headset PQA data we copied locally into the index we've just created.

# %%
import re
import json
from tqdm.contrib.concurrent import process_map
from multiprocessing import cpu_count

def load_pqa_as_json(file_name,number_rows=1000):
    result=[]
    with open(file_name) as f:
        i=0
        for line in f:
            data = json.loads(line)
            result.append(data)
            # refinedStr = re.sub(r'\W+', '', data["question_text"])
            # result.append({"question": str(data["question_text"])})
            i+=1
            if(i == number_rows):
                break
    return result

qa_list_json = load_pqa_as_json('amazon-pqa/amazon_pqa_headsets.json',number_rows=1000)

def es_import(question):
    aos_client.index(index='headset_pqa', body=question)

# %%
qa_list_json[:2]
# Out:
# [{'question_id': 'Tx39GCUOS5AYAFK',
#   'question_text': 'does this work with cisco ip phone 7942',
#   'asin': 'B000LSZ2D6',
#   'bullet_point1': 'Noise-Canceling microphone filters out background sound',
#   'bullet_point2': 'HW251N P/N 75100-06',
#   'bullet_point3': 'Uses Plantronics QD Quick Disconnect Connector. Must be used with Plantronics Amp or with proper phone or USB adapter cable',
#   'bullet_point4': 'Connectivity Technology: Wired, Earpiece Design: Over-the-head, Earpiece Type: Monaural, Host Interface: Proprietary, Microphone Design: Boom, Microphone Technology: Noise Canceling, Product Model: HW251N, Product Series: SupraPlus, Standard Warranty: 2 Year',
#   'bullet_point5': 'Easy Lightweight Wear -Leaving One Ear Uncovered For Person-to-Person Conversations',
#   'product_description': '',
#   'brand_name': 'Plantronics',
#   'item_name': 'Plantronics HW251N SupraPlus Wideband Headset (64338-31)',
#   'question_type': 'yes-no',
#   'answer_aggregated': 'neutral',
#   'answers': [{'answer_text': 'Use the Plantronics compatibility guide to see what is compatible with your phone. http://www.plantronics.com/us/compatibility-guide/'},
#    {'answer_text': 'I think that you will need a extra cord, but, To avoid offering you any false information,   We highly recommend contacting the manufacturer of this product for more specific information.   if you are not sure about it, you can go first to :  http://www.plantronics.com/us/support/  or call Plantronics TOLL FREE SUPPORT: 1-855-765-7878 24-HOUR SUPPORT SUNDAY 2PM-FRIDAY 5PM (PT)  they will answer all the questions you need to know about it.'},
#    {'answer_text': "I'm really not positive. It works with our phones that include model numbers 7941, 7945 and 7961."}]},
#  {'question_id': 'TxH4TPAQFBLE5L',
#   'question_text': 'Is this compatible with the cisco ip phone 7970 / 7961 models?',
#   'asin': 'B000LSZ2D6',
#   'bullet_point1': 'Noise-Canceling microphone filters out background sound',
#   'bullet_point2': 'HW251N P/N 75100-06',
#   'bullet_point3': 'Uses Plantronics QD Quick Disconnect Connector. Must be used with Plantronics Amp or with proper phone or USB adapter cable',
#   'bullet_point4': 'Connectivity Technology: Wired, Earpiece Design: Over-the-head, Earpiece Type: Monaural, Host Interface: Proprietary, Microphone Design: Boom, Microphone Technology: Noise Canceling, Product Model: HW251N, Product Series: SupraPlus, Standard Warranty: 2 Year',
#   'bullet_point5': 'Easy Lightweight Wear -Leaving One Ear Uncovered For Person-to-Person Conversations',
#   'product_description': '',
#   'brand_name': 'Plantronics',
#   'item_name': 'Plantronics HW251N SupraPlus Wideband Headset (64338-31)',
#   'question_type': 'yes-no',
#   'answer_aggregated': 'yes',
#   'answers': [{'answer_text': 'Don’t know. Call Plantronics'},
#    {'answer_text': "Well...Don't know."},
#    {'answer_text': "This headset should work but it requires a separate adapter to go with it in order too connect with this telephone. Below is a headset that includes the cord you'll need to connect with your Cisco phones.  https://www.amazon.com/dp/B01MYGZGUV"},
#    {'answer_text': 'Hello! Yes it is compatible, however please note you will need an adapter cable in order to plug it into the phone. The model of the cable depends on the phone that you have. The compatible model for both phones is a U10 cable, Part Number: 26716-01. Feel free to contact our Customer Care Team at: 800-985-9815 if you have any other questions!'}]}]

# %%
workers = 4 * cpu_count()
    
process_map(es_import, qa_list_json, chunksize=100)

# %%
for query in qa_list_json:
    es_import(query)

# %% [markdown]
# To validate the load, we'll query the number of documents number in the index. We should have 1000 hits in the index.

# %%
res = aos_client.search(index="headset_pqa", body={"query": {"match_all": {}}})
print("Records found: %d " % res['hits']['total']['value'])
# Out:
# Records found: 1000

# %% [markdown]
# ### 7. Run a " Simple Text Search"
#
# Now that we've loaded our data, let's run a keyword search for the question "does this work with xbox?", using the default OpenSearch query, and display the results.

# %%
import pandas as pd
query={
  "size": 10,
  "query": {
    "match": {
      "question_text": "does this work with xbox?"
    }
  }
}
res = aos_client.search(index="headset_pqa", body=query)
query_result=[]
for hit in res['hits']['hits']:
    row=[hit['_id'],hit['_score'],hit['_source']['question_text'],hit['_source']['answers'][0]['answer_text']]
    query_result.append(row)

query_result_df = pd.DataFrame(data=query_result,columns=["_id","_score","question","answer"])
with pd.option_context("display.max_colwidth", 120):
    display(query_result_df)
# Out:
#                     _id    _score  \
# 0  olJGq4wBZBEtYQQvFRaF  9.786783
# 1  rlJHq4wBZBEtYQQv4Bi0  9.415402
# 2  IFJHq4wBZBEtYQQvZBip  8.508419
# 3  GFJFq4wBZBEtYQQvmBYq  8.366218
# 4  KVJHq4wBZBEtYQQvbBgd  7.526715
# 5  MFJHq4wBZBEtYQQvchi5  7.401660
# 6  YlJFq4wBZBEtYQQv3BYt  7.353278
# 7  -FJHq4wBZBEtYQQvQhec  7.270713
# 8  o1JIq4wBZBEtYQQvsRkj  7.093800
# 9  _1JHq4wBZBEtYQQvSBd0  7.038970
#
#                                              question  \
# 0                       Does this work with xbox one?
# 1                   Does this work with the xbox one?
# 2                         does this work on xbox one?
# 3                      Does this work for xbox one S?
# 4                          Does it work for Xbox 360?
# 5                          Does it work for xbox one?
# 6                               work with xbox one???
# 7                             Does this work with PS4
# 8  Can this work with an xbox one with the adpater???
# 9                      will these work with xbox one?
#
#                                                                                                                     answer
# 0                                                                                              sorry, Im not an xbox user.
# 1                                              Yeah of course , but you must have an adapter to use this beautiful headset
# 2                                                                                                      I'm sorry, but not!
# 3                                                                                                          It should work.
# 4                                                                                          Sorry , it can't  .Just for PS4
# 5                                           Thanks for your inquiry, it just works with PS4. Hope this is helpful for you.
# 6                                                                     with the stereo headset adapter with is not included
# 7                                                                                                                      yes
# 8  Yes but the audio is not very good. I recommend using the Mixamp and the adapter. The adapter I use for just voice chat
# 9                                                                                                                      Yes

# %% [markdown]
# ### 8. Search across multiple fields
#
# Search across multiple fields could bring more results and scored based on BM25 relevancy

# %%
import pandas as pd
query={
  "size": 10,
  "query": {
    "multi_match": {
      "query": "does this work with xbox?",
      "fields": ["question_text","bullet_point*", "answers.answer_text", "item_name"]
    }
  }
}
res = aos_client.search(index="headset_pqa", body=query)

query_result=[]
for hit in res['hits']['hits']:
    row=[hit['_id'],hit['_score'],hit['_source']['question_text'],hit['_source']['answers'][0]['answer_text']]
    query_result.append(row)

query_result_df = pd.DataFrame(data=query_result,columns=["_id","_score","question","answer"])
with pd.option_context("display.max_colwidth", 120):
    display(query_result_df)
# Out:
#                     _id     _score  \
# 0  b1JFq4wBZBEtYQQv5xYP  11.929837
# 1  mlJIq4wBZBEtYQQvqRm9   9.800990
# 2  olJGq4wBZBEtYQQvFRaF   9.786783
# 3  rlJHq4wBZBEtYQQv4Bi0   9.415402
# 4  GlJFq4wBZBEtYQQvmRbS   9.162766
# 5  k1JGq4wBZBEtYQQvCBY5   8.921030
# 6  IFJHq4wBZBEtYQQvZBip   8.508419
# 7  GFJFq4wBZBEtYQQvmBYq   8.366218
# 8  QlJHq4wBZBEtYQQvgRin   8.153154
# 9  UVJGq4wBZBEtYQQvsBfK   7.888779
#
#                                                                                                                   question  \
# 0  Can someone help me figure out how to get the mic working on the head set with a xbox one. we have the adapter cord ...
# 1                                                       DOes it work with Xbox 360 or do you need the mixamp or chat cord?
# 2                                                                                            Does this work with xbox one?
# 3                                                                                        Does this work with the xbox one?
# 4                                               So, these are totally comparable with the Xbox One?. Any adapters needed?.
# 5                                                                  How do I know which version of the Xbox one that I have
# 6                                                                                              does this work on xbox one?
# 7                                                                                           Does this work for xbox one S?
# 8                                                                                               Will it work for xbox one?
# 9                                                                                                Does it work for android?
#
#                                                                                                                     answer
# 0  Hi J. Klenske, if your xbox one is the new version, you can just use with a normal 2 in 1 splitter cable. If your xb...
# 1                                          This was a gift for my son.  I asked him and he said that you need a chat cord.
# 2                                                                                              sorry, Im not an xbox user.
# 3                                              Yeah of course , but you must have an adapter to use this beautiful headset
# 4                                                                   Per Skullcandy....yes it works directly with xbox.  Al
# 5  There is Xbox one, Xbox one s, now Xbox one x. It will say on the box it came in. It doesn't matter which version th...
# 6                                                                                                      I'm sorry, but not!
# 7                                                                                                          It should work.
# 8                               Sorry, it is not compatible with PS4 Xbox one. It could work with PCs, PS2, PS3, Xbox 360.
# 9                                                                                                It does work with Android

# %% [markdown]
# ### 9. Search with Field preference or boosting
#
# When searching across fields, all fields given the same priority by default. But you can control the preference by giving static boost score to each field

# %%
import pandas as pd
query={
  "size": 10,
  "query": {
    "multi_match": {
      "query": "does this work with xbox?",
      "fields": ["question_text^2", "bullet_point*", "answers.answer_text^2", "item_name^1.5"]
    }
  }
}
res = aos_client.search(index="headset_pqa", body=query)

query_result=[]
for hit in res['hits']['hits']:
    row=[hit['_id'],hit['_score'],hit['_source']['question_text'],hit['_source']['answers'][0]['answer_text']]
    query_result.append(row)

query_result_df = pd.DataFrame(data=query_result,columns=["_id","_score","question","answer"])
with pd.option_context("display.max_colwidth", 120):
    display(query_result_df)
# Out:
#                     _id     _score  \
# 0  mlJIq4wBZBEtYQQvqRm9  19.601980
# 1  olJGq4wBZBEtYQQvFRaF  19.573566
# 2  rlJHq4wBZBEtYQQv4Bi0  18.830805
# 3  GlJFq4wBZBEtYQQvmRbS  18.325531
# 4  k1JGq4wBZBEtYQQvCBY5  17.842060
# 5  IFJHq4wBZBEtYQQvZBip  17.016838
# 6  GFJFq4wBZBEtYQQvmBYq  16.732435
# 7  QlJHq4wBZBEtYQQvgRin  16.306309
# 8  UVJGq4wBZBEtYQQvsBfK  15.777558
# 9  plJGq4wBZBEtYQQv_BcC  15.595388
#
#                                                                      question  \
# 0          DOes it work with Xbox 360 or do you need the mixamp or chat cord?
# 1                                               Does this work with xbox one?
# 2                                           Does this work with the xbox one?
# 3  So, these are totally comparable with the Xbox One?. Any adapters needed?.
# 4                     How do I know which version of the Xbox one that I have
# 5                                                 does this work on xbox one?
# 6                                              Does this work for xbox one S?
# 7                                                  Will it work for xbox one?
# 8                                                   Does it work for android?
# 9            Can I use my wireless bluetotth head phones for sound with game?
#
#                                                                                                                     answer
# 0                                          This was a gift for my son.  I asked him and he said that you need a chat cord.
# 1                                                                                              sorry, Im not an xbox user.
# 2                                              Yeah of course , but you must have an adapter to use this beautiful headset
# 3                                                                   Per Skullcandy....yes it works directly with xbox.  Al
# 4  There is Xbox one, Xbox one s, now Xbox one x. It will say on the box it came in. It doesn't matter which version th...
# 5                                                                                                      I'm sorry, but not!
# 6                                                                                                          It should work.
# 7                               Sorry, it is not compatible with PS4 Xbox one. It could work with PCs, PS2, PS3, Xbox 360.
# 8                                                                                                It does work with Android
# 9                                        My son doesn’t think you can. He uses his wired headset that he uses for his xbox

# %% [markdown]
# ### 10. Compound queries with `bool`
#
# With `bool` queries, you can give more preference based on other field values/existance. In the below query, it will get higher score if `answer_aggregated` is `netural`

# %%
import pandas as pd
query={
  "query": {
    "bool": {
      "must": [
        {
          "multi_match": {
            "query": "does this work with xbox?",
            "fields": [ "question_text^2", "bullet_point*", "answers.answer_text^2","item_name^2"]
          }
        }
      ],
      "should": [
        {
          "term": {
            "answer_aggregated.keyword": {
              "value": "neutral"
            }
          }
        }
      ]
    }
  }
}
res = aos_client.search(index="headset_pqa", body=query)
query_result=[]
for hit in res['hits']['hits']:
    row=[hit['_id'],hit['_score'],hit['_source']['question_text'],hit['_source']['answers'][0]['answer_text']]
    query_result.append(row)

query_result_df = pd.DataFrame(data=query_result,columns=["_id","_score","question","answer"])
with pd.option_context("display.max_colwidth", 120):
    display(query_result_df)
# Out:
#                     _id     _score  \
# 0  rlJHq4wBZBEtYQQv4Bi0  20.291574
# 1  mlJIq4wBZBEtYQQvqRm9  19.601980
# 2  olJGq4wBZBEtYQQvFRaF  19.573566
# 3  IFJHq4wBZBEtYQQvZBip  18.477608
# 4  GlJFq4wBZBEtYQQvmRbS  18.325531
# 5  GFJFq4wBZBEtYQQvmBYq  18.181099
# 6  k1JGq4wBZBEtYQQvCBY5  17.842060
# 7  QlJHq4wBZBEtYQQvgRin  17.658031
# 8  UVJGq4wBZBEtYQQvsBfK  17.129282
# 9  KVJHq4wBZBEtYQQvbBgd  16.405153
#
#                                                                      question  \
# 0                                           Does this work with the xbox one?
# 1          DOes it work with Xbox 360 or do you need the mixamp or chat cord?
# 2                                               Does this work with xbox one?
# 3                                                 does this work on xbox one?
# 4  So, these are totally comparable with the Xbox One?. Any adapters needed?.
# 5                                              Does this work for xbox one S?
# 6                     How do I know which version of the Xbox one that I have
# 7                                                  Will it work for xbox one?
# 8                                                   Does it work for android?
# 9                                                  Does it work for Xbox 360?
#
#                                                                                                                     answer
# 0                                              Yeah of course , but you must have an adapter to use this beautiful headset
# 1                                          This was a gift for my son.  I asked him and he said that you need a chat cord.
# 2                                                                                              sorry, Im not an xbox user.
# 3                                                                                                      I'm sorry, but not!
# 4                                                                   Per Skullcandy....yes it works directly with xbox.  Al
# 5                                                                                                          It should work.
# 6  There is Xbox one, Xbox one s, now Xbox one x. It will say on the box it came in. It doesn't matter which version th...
# 7                               Sorry, it is not compatible with PS4 Xbox one. It could work with PCs, PS2, PS3, Xbox 360.
# 8                                                                                                It does work with Android
# 9                                                                                          Sorry , it can't  .Just for PS4

# %% [markdown]
# ### 11. Use custom scoring with function score queries
#
# Function score are handy queries to overwrite the default BM-25 scoring. In the below query, it recalculates the score based on how many times the question was answered before.

# %%
import pandas as pd
query={
  "query": {
    "function_score": {
      "query": {
        "bool": {
          "must": [
            {
              "multi_match": {
                "query": "does this work with xbox?",
                "fields": ["question_text^5","bullet_point*","answers.answer_text^2", "item_name^2" ]
              }
            }
          ],
          "should": [
            {
              "term": {
                "answer_aggregated.keyword": {
                  "value": "neutral"
                }
              }
            }
          ]
        }
      },
      "functions": [
        {
          "script_score": {
            "script": "_score * 0.25 * doc['answers.answer_text.keyword'].length"
          }
        }
      ]
    }
  }
}
res = aos_client.search(index="headset_pqa", body=query)
print("Got %d Hits:" % res['hits']['total']['value'])
query_result=[]
for hit in res['hits']['hits']:
    row=[hit['_id'],hit['_score'],hit['_source']['question_text'],hit['_source']['answers'][0]['answer_text']]
    query_result.append(row)

query_result_df = pd.DataFrame(data=query_result,columns=["_id","_score","question","answer"])
with pd.option_context("display.max_colwidth", 120):
    display(query_result_df)
# Out:
# Got 984 Hits:
#                     _id      _score                                 question  \
# 0  olJGq4wBZBEtYQQvFRaF  1795.89600            Does this work with xbox one?
# 1  rlJHq4wBZBEtYQQv4Bi0  1766.93710        Does this work with the xbox one?
# 2  _1JHq4wBZBEtYQQvSBd0  1238.67750           will these work with xbox one?
# 3  JFJFq4wBZBEtYQQvohYy  1136.27940              Do they work with xbox one?
# 4  p1JIq4wBZBEtYQQvtBl3  1134.56000       Do they work with Xbox One system?
# 5  MlJFq4wBZBEtYQQvsBYc   840.70120  Does this work with PC? If it does how?
# 6  FlJIq4wBZBEtYQQvOxl0   823.28650             Does it work with galaxy s7?
# 7  nVJHq4wBZBEtYQQv0hhi   806.45420  Does this work with a Blackberry phone?
# 8  DlJIq4wBZBEtYQQvNBne   775.08484  does this work with a kindle fire hd 8?
# 9  G1JIq4wBZBEtYQQvPxmS   759.95030   Does the M70 work with Android phones?
#
#                                                                                                                     answer
# 0                                                                                              sorry, Im not an xbox user.
# 1                                              Yeah of course , but you must have an adapter to use this beautiful headset
# 2                                                                                                                      Yes
# 3                                                   No they don't , but let's hope that Microsoft makes a wireless headset
# 4                                                          If you have the Xbox controller stereo headset adapter then yes
# 5  Yes it does work on pc.   I personally just plug it into the headphone jack on my pc. If you want to use the extensi...
# 6              Yes, I've used this with the Galaxy S7 and j7. Hands-free dialing from the phone book also works very well.
# 7                                                                                        You need a 2.5 adapter with it. ,
# 8                                  Hi!  I believe so.  I use it with Samsung devices and it works well. So it should work.
# 9                                                                                       Hello, Yes, I think so, thank you.

# %% [markdown]
# ### 12. Observe The Results and Refine
#
# Congratulations, you've now explored the possiblities of text search on the data in OpenSearch.
#
# If you take a look at the results above, you'll notice that the results match one or more of the key words from our question, most commonly the words "work" and "xbox".  You'll also notices that a lot of these results aren't relevant to our original question, such as "Does it work on PS3?" and "Does it work for computers". In Module 3, we'll instead use semantic search to make the result more relevant.

# %% [markdown]
# ### Store Variables Used for the Next Notebook
#
# There are a few values you will need for the next notebook, execute the cells below to store them so they can be copied and pasted into the next part of the exercise.

# %%
# %store outputs
# %store bucket
# %store aos_host
